# %%
import autogen

# %%
llm_config={"model": "gpt-4o-mini"}

# %%
customer_statement="""
I want to create an educational portal where students and teachers can interact.
The portal should include features such as course management, assignment submission, grading system, 
and discussion forums. Teachers should be able to create and manage courses, while students should be able
to enroll, submit assignments, and receive feedback. The system should also support document sharing and 
administrative controls.
"""

# %%
customer_proxy = autogen.ConversableAgent(
    name="Customer",
    system_message="A customer providing requirements for an educational portal to the Project Manager.",
    code_execution_config=False,
    llm_config=llm_config,
    human_input_mode="NEVER",
)

# %%
project_manager = autogen.ConversableAgent(
    name="Project_Manager",
    system_message="""You are a project manager coordinating the development of an educational portal. Your responsibilities include:",
    1. Receiving requirements from the customer
    2. Delegating tasks to appropriate team members (Requirement Engineer, System Engineer, Software Engineer, Test Engineer, and Document Enginner)
    3. Collecting outputs from each engineer
    4. Compiling a comprehensive project plan with timelines after gathering estimated effort from each engineer.
    5. Presenting the final project plan in a tabular form to the customer""",
    code_execution_config=False,
    llm_config=llm_config,
    human_input_mode="NEVER",
)

# %%
requirements_engineer = autogen.ConversableAgent(
    name="Requirements_Engineer",
    system_message="""You are a requirements engineer working on an educational software. Your tasks are:
    1. Analyze the project requirements from the project manager
    2. Create a detailed requirements document with functional and non-functional requirements
    3. Identify all use cases for students, teachers, and administrators
    4. Estimate effort based on:
    - Total requirements: Estimate based on feature complexity
    - Productivity: 5 requirements per day
    - Effort = Total requirements / Productivity
    5. Return the requirements document and effort estimate to the project manager""",
    code_execution_config=False,
    llm_config=llm_config,
    human_input_mode="NEVER",
)

# %%
system_engineer = autogen.ConversableAgent(
    name="System_Engineer",
    system_message= """You are a system engineer working on an educational software. Your responsibilities are:
    1. Receive requirements document from project manager
    2. Create detailed system design including:
    - Architecture diagrams
    - Database schema
    - API specifications
    - UI wireframes
    3. Estimate effort based on:
    - Total design pages: 1 page per 5 requirements
    - Productivity: 5 pages per day
    - Effort = Total pages / Productivity
    4. Return effort estimate to project manager""",
    code_execution_config=False,
    llm_config=llm_config,
    human_input_mode="NEVER",
)

# %%
software_developer = autogen.ConversableAgent(
    name="Software_Developer",
    system_message="""You are a software developer working on an educational software. Your tasks are:
    1. Receive design document from project manager
    2. Develop the application including:
    - Frontend components
    - Backend services
    - Database integration
    3. Estimate effort based on:
    - Lines of code: 100 SLOC per design page
    - Productivity: 50 SLOC per day
    - Effort = Total SLOC / Productivity
    4.Return effort estimate to project manager""",
    code_execution_config=False,
    llm_config=llm_config,
    human_input_mode="NEVER",
)

# %%
test_engineer = autogen.ConversableAgent(
    name="Test_Engineer",
    system_message="""You are a test engineer working on an educational software. Your responsibilities are:
    1. Receive requirements and design documents from project manager
    2. Create test plan including:
    - Unit tests
    - Integration tests
    - UI tests
    - Performance tests
    3. Estimate effort based on:
    - Test cases: 2 test cases per requirement
    - Productivity: 2 test cases per day (including execution)
    - Effort = Total test cases / Productivity
    4. Return effort estimate to project manager""",
    code_execution_config=False,
    llm_config=llm_config,
    human_input_mode="NEVER",
)

# %%
documentation_engineer = autogen.ConversableAgent(
    name="Documentation_Engineer",
    system_message="""You are a Document engineer working on an educational software. Your tasks are:
    1. Receive all project documents from project manager
    2. Create documentation including:
    - User manuals
    - Administrator guides
    - API documentation
    - Training materials
    3. Estimate effort based on:
    - Documentation pages: 1 page per 3 requirements
    - Productivity: 3 pages per day
    - Effort = Total pages / Productivity
    4. Return effort estimate to project manager""",
    code_execution_config=False,
    llm_config=llm_config,
    human_input_mode="NEVER",
)

# %%
# Initialize GroupChat
groupchat = autogen.GroupChat(
    agents=[
        customer_proxy,
        project_manager,
        requirements_engineer,
        system_engineer,
        software_developer,
        test_engineer,
        documentation_engineer,
    ],
    messages=[],
    speaker_selection_method="round_robin",  # Automatically selects the next speaker
    max_round=9,
)

# %%
manager = autogen.GroupChatManager(
    groupchat=groupchat, 
    llm_config=llm_config
)

# %%
chat_result = customer_proxy.initiate_chat(
    manager,
    message=customer_statement,
)
# Out:
# Customer (to chat_manager):
#
#
# I want to create an educational portal where students and teachers can interact.
# The portal should include features such as course management, assignment submission, grading system,
# and discussion forums. Teachers should be able to create and manage courses, while students should be able
# to enroll, submit assignments, and receive feedback. The system should also support document sharing and
# administrative controls.
#
#
# --------------------------------------------------------------------------------
#
# Next speaker: Project_Manager
#
# Project_Manager (to chat_manager):
#
# Thank you for providing the requirements for the educational portal. I will get started by delegating tasks to the appropriate team members based on these requirements. Here’s how I plan to proceed:
#
# ### 1. Requirement Gathering:
# I'll share your requirements with the Requirement Engineer to ensure all details are documented and understood clearly.
#
# ### 2. Task Delegation:
# I will delegate specific tasks to each team member as follows:
#
# - **Requirement Engineer**: Gather detailed requirements for each feature (course management, assignment submission, grading system, discussion forums, document sharing, and administrative controls).
# - **System Engineer**: Design the architecture of the portal, focusing on system integrations and scalability.
# - **Software Engineer**: Develop the application, including front-end and back-end development for all features.
# - **Test Engineer**: Create a testing plan that includes unit tests, integration tests, and user acceptance testing.
# - **Document Engineer**: Prepare user documentation and training materials for both students and teachers.
#
# ### 3. Collecting Outputs:
# Once tasks are delegated, I will gather the outputs from each engineer, which will include:
#
# - Requirement specifications from the Requirement Engineer.
# - Technical architecture document from the System Engineer.
# - Development estimates and plan from the Software Engineer.
# - Testing plan from the Test Engineer.
# - Documentation drafts from the Document Engineer.
#
# ### 4. Compiling the Project Plan:
# After receiving the outputs, I will compile a comprehensive project plan with estimated effort and timelines from each engineer.
#
# ### 5. Presenting the Project Plan:
# Finally, I will prepare a tabular form of the project plan that outlines the tasks, responsible persons, timelines, and deliverables to present it to you.
#
# ### Next Steps:
# Let's proceed with gathering more detailed requirements from the Requirement Engineer. I will follow up with you soon to update you on the progress and share the draft of the project plan.
#
# If you have any specific priorities or additional requirements, please let me know!
#
# --------------------------------------------------------------------------------
#
# Next speaker: Requirements_Engineer
#
# Requirements_Engineer (to chat_manager):
#
# ### Requirements Document for Educational Portal
#
# #### 1. Introduction
# This document outlines the functional and non-functional requirements for the educational portal designed to facilitate interaction between students and teachers. It serves as a guideline for the development team and will assist in ensuring that the project objectives are met.
#
# #### 2. Functional Requirements
# 1. **Course Management**
#    - Teachers can create new courses including details such as title, description, syllabus, and schedule.
#    - Teachers can update and delete existing courses.
#    - Students can view the list of available courses.
#    - Students can enroll and unenroll from courses.
#
# 2. **Assignment Management**
#    - Teachers can create assignments linked to their courses with due dates and guidelines.
#    - Students can submit their assignments electronically.
#    - Teachers can review assignments and provide feedback.
#
# 3. **Grading System**
#    - Teachers can assign grades to student submissions.
#    - Students can view their grades and feedback.
#    - Generate reports on student performance for teachers.
#
# 4. **Discussion Forums**
#    - Students and teachers can create topics for discussions related to the courses.
#    - Users can post questions, answers, and comments.
#    - Ability to moderate discussions by teachers.
#
# 5. **Document Sharing**
#    - Teachers can upload course materials and supplementary documents for students to access.
#    - Students can download shared documents.
#    - Document version control to manage updates.
#
# 6. **Administrative Controls**
#    - Admins can manage user accounts (add, remove, modify roles).
#    - Admin can review user activity and system usage reports.
#    - Set permissions for course visibility.
#
# #### 3. Non-Functional Requirements
# 1. **Performance**
#    - The system should support simultaneous access by at least 500 users.
#    - All pages should load within 3 seconds under peak load.
#
# 2. **Security**
#    - Implement role-based access control (RBAC) to manage user permissions.
#    - Ensure data protection and encryption for sensitive user data.
#
# 3. **Usability**
#    - The interface should be user-friendly with easy navigation for students and teachers.
#    - Provide accessibility options for users with disabilities.
#
# 4. **Reliability**
#    - System uptime must be at least 99.5%.
#    - Regular backups of course content and user data should be maintained.
#
# 5. **Scalability**
#    - The system should be designed to accommodate future features and increased user load without significant restructuring.
#
# #### 4. Use Cases
# - **Students**
#   - Enroll in Courses
#   - Submit Assignments
#   - Participate in Discussion Forums
#   - View Grades and Feedback
#   - Download Course Materials
#
# - **Teachers**
#   - Create and Manage Courses
#   - Create and Grade Assignments
#   - Facilitate Discussions
#   - Provide Feedback
#   - Upload Course Documents
#
# - **Administrators**
#   - Manage User Accounts
#   - Monitor System Activity
#   - Generate Usage Reports
#   - Configure System Settings
#
# #### 5. Effort Estimation
# - **Total Requirements**: 18 unique requirements identified
# - **Productivity**: 5 requirements per day
#
# **Effort Calculation**:
# - Effort = Total requirements / Productivity
# - Effort = 18 requirements / 5 (requirements/day) = 3.6 days
#
# ### 6. Conclusion
# This requirements document captures the essential features and functionalities for the educational portal. The effort estimate indicates that the initial detailed requirements can be gathered in approximately 4 days (rounding up). Subsequent phases will include implementation, testing, and documentation as outlined.
#
# Please review and provide feedback or any additional requirements that may need to be addressed.
#
# --------------------------------------------------------------------------------
#
# Next speaker: System_Engineer
#
# System_Engineer (to chat_manager):
#
# ### System Design for Educational Portal
#
# #### 1. Architecture Diagrams
# The architecture of the educational portal consists of the following key components:
#
# - **Client-Side Interface**: A responsive web application accessible by students, teachers, and admins.
# - **Server-Side API**: RESTful APIs to handle requests from the client-side and manage business logic.
# - **Database Server**: A relational database to store user data, course details, assignments, grades, and forums.
# - **File Storage**: A cloud or local storage solution for document sharing and course materials.
# - **Authentication Service**: A secure service to handle user authentication and role-based access.
#
# ![Architecture Diagram](#) *(Insert Architecture Diagram Here)*
#
# #### 2. Database Schema
# The database schema will include the following tables:
#
# 1. **Users Table**
#    - UserID (Primary Key)
#    - Username
#    - Password (hashed)
#    - Role (student, teacher, admin)
#    - Email
#    - CreatedAt
#    - UpdatedAt
#
# 2. **Courses Table**
#    - CourseID (Primary Key)
#    - Title
#    - Description
#    - Syllabus
#    - Schedule
#    - CreatedBy (UserID of the Teacher)
#    - CreatedAt
#    - UpdatedAt
#
# 3. **Enrollments Table**
#    - EnrollmentID (Primary Key)
#    - CourseID (Foreign Key)
#    - UserID (Foreign Key - Student)
#    - EnrolledAt
#
# 4. **Assignments Table**
#    - AssignmentID (Primary Key)
#    - CourseID (Foreign Key)
#    - Title
#    - DueDate
#    - Guidelines
#    - CreatedAt
#    - UpdatedAt
#
# 5. **Submissions Table**
#    - SubmissionID (Primary Key)
#    - AssignmentID (Foreign Key)
#    - UserID (Foreign Key - Student)
#    - SubmissionDate
#    - SubmittedFilePath
#    - Feedback
#    - Grade
#
# 6. **Forums Table**
#    - ForumID (Primary Key)
#    - CourseID (Foreign Key)
#    - Topic
#    - CreatedBy (UserID)
#    - CreatedAt
#
# 7. **Posts Table**
#    - PostID (Primary Key)
#    - ForumID (Foreign Key)
#    - UserID (Foreign Key)
#    - Content
#    - CreatedAt
#
# ![Database Schema](#) *(Insert Database Schema Diagram Here)*
#
# #### 3. API Specifications
# Here are the key API endpoints for interaction:
#
# - **User Management**
#   - `POST /api/users/register` - Register a new user
#   - `POST /api/users/login` - Authenticate and login user
#   - `GET /api/users/{id}` - Get user profile details
#
# - **Course Management**
#   - `POST /api/courses` - Create a new course
#   - `GET /api/courses` - List available courses
#   - `GET /api/courses/{id}` - Get course details
#   - `PUT /api/courses/{id}` - Update course details
#   - `DELETE /api/courses/{id}` - Delete a course
#
# - **Assignment Management**
#   - `POST /api/assignments` - Create a new assignment
#   - `GET /api/courses/{courseId}/assignments` - List assignments for a course
#   - `POST /api/assignments/{id}/submit` - Submit an assignment
#
# - **Forum Management**
#   - `POST /api/forums` - Create a new forum topic
#   - `GET /api/forums/{courseId}` - Get all forum topics for a course
#   - `POST /api/forums/{forumId}/posts` - Add a post to a forum
#
# ![API Specifications](#) *(Insert API Specification Documentation Here)*
#
# #### 4. UI Wireframes
# Below are wireframe suggestions for the key user interfaces:
#
# 1. **Home Page**: Course catalog overview with enrollment options.
# 2. **Course Page**: Detailed information on the selected course including syllabus, assignments, and discussion forum.
# 3. **Assignment Submission Page**: Area where students can submit their work for evaluation.
# 4. **Discussion Forum UI**: User interface for posting and replying to threads.
# 5. **Grading Overview**: Interface for teachers to input and view grades.
#
# ![UI Wireframes](#) *(Insert UI Wireframe Images Here)*
#
# #### 5. Effort Estimation
# Given the breakdown of requirements:
# - **Total Requirements Identified**: 18
# - **Estimated Total Pages for Design**: \( \frac{18 \text{ requirements}}{5 \text{ requirements per page}}= 3.6 \) pages, rounding up to 4 pages.
# - **Productivity Rate**: 5 pages per day.
#
# **Effort Calculation**:
# - Effort = Total pages / Productivity
# - Effort = \( \frac{4 \text{ pages}}{5 \text{ pages/day}} \) = 0.8 days
#
# ### 6. Conclusion
# The system design encompasses the necessary architecture, database schema, API specifications, and UI components required for the educational portal. The estimated effort for creating detailed designs is approximately **1 day** (rounding up).
#
# Please review and let me know if any adjustments or additional details are needed before I return this estimate to the project manager.
#
# --------------------------------------------------------------------------------
#
# Next speaker: Software_Developer
#
# Software_Developer (to chat_manager):
#
# ### Software Development Effort Estimation for Educational Portal
#
# After receiving the detailed requirements and system design documents, it's time to estimate the effort required for the development of the educational portal including frontend components, backend services, and database integration.
#
# #### 1. Calculate Total Lines of Code (SLOC)
# The development can be divided into the following categories based on the functional requirements:
#
# - **Course Management**: 100 SLOC
# - **Assignment Management**: 100 SLOC
# - **Grading System**: 100 SLOC
# - **Discussion Forums**: 100 SLOC
# - **Document Sharing**: 100 SLOC
# - **Administrative Controls**: 100 SLOC
#
# **Total Lines of Code (SLOC)** = 100 SLOC * 6 features = **600 SLOC**
#
# #### 2. Productivity Estimation
# As provided, the productivity is estimated at 50 SLOC per day.
#
# #### 3. Effort Calculation
# Using the formula:
# - **Effort** = Total SLOC / Productivity
#
# **Effort** = 600 SLOC / 50 SLOC per day = **12 days**
#
# ### Summary
# The estimated effort to develop the educational portal is **12 days**. This includes the necessary time to work on frontend components, backend services, and integrate the database as per the features and functionality outlined in the requirements and system design documents.
#
# I will now return this effort estimate to the project manager for further planning and decision-making. If there are any adjustments or additional considerations to factor in, please let me know!
#
# --------------------------------------------------------------------------------
#
# Next speaker: Test_Engineer
#
# Test_Engineer (to chat_manager):
#
# ### Test Plan for Educational Portal
#
# Based on the requirements, design specifications, and development effort estimates provided, I will create a test plan that includes unit tests, integration tests, UI tests, and performance tests. Below is the detailed breakdown of the testing strategy.
#
# #### 1. Test Types
# - **Unit Tests**: Validate the functionality of each individual component or method.
# - **Integration Tests**: Ensure that various components (e.g., frontend and backend, database interactions) work together as expected.
# - **UI Tests**: Verify the user interface for usability and responsive behavior across different devices.
# - **Performance Tests**: Assess system performance under various conditions, particularly focusing on system load and response times.
#
# #### 2. Test Cases Estimation
# We will derive two test cases for each functional requirement.
#
# - **Functional Requirements**: 18 unique requirements identified.
# - **Total Test Cases**: 18 requirements * 2 test cases per requirement = **36 test cases**.
#
# #### 3. Effort Calculation
# We will use the productivity defined as 2 test cases executed per day.
#
# - **Total Test Cases**: 36
# - **Productivity**: 2 test cases per day
#
# **Effort Calculation**:
# - **Effort = Total test cases / Productivity**
# - Effort = 36 test cases / 2 test cases per day = **18 days**
#
# ### Summary
# The estimated effort required to thoroughly test the educational portal is **18 days**. This encompasses the time necessary to develop and execute unit tests, integration tests, UI tests, and performance tests.
#
# I will return this estimate to the project manager for review and planning in alignment with the overall project schedule. If there are any further requirements or adjustments needed, please let me know!
#
# --------------------------------------------------------------------------------
#
# Next speaker: Documentation_Engineer
#
# Documentation_Engineer (to chat_manager):
#
# ### Comprehensive Effort Estimation for Educational Portal Documentation
#
# Now that we've received the necessary information from all team members, we can summarize the effort required for documentation based on the functionalities and estimated efforts provided.
#
# #### 1. Documentation Tasks Overview
# The documentation will include the following deliverables:
# - User Manuals
# - Administrator Guides
# - API Documentation
# - Training Materials
#
# #### 2. Documentation Pages Estimation
# **Total Requirements**: 18 unique requirements
#
# Assuming **1 documentation page for every 3 requirements**, we calculate the total pages as follows:
# - Total Documentation Pages = \( \frac{18 \text{ requirements}}{3} = 6 \) pages
#
# #### 3. Productivity and Effort Calculation
# Given the productivity rate of **3 pages per day**:
# - **Effort** = Total Documentation Pages / Productivity
# - Effort = \( \frac{6 \text{ pages}}{3 \text{ pages/day}} = 2 \text{ days} \)
#
# ### Summary
# The estimated effort required to produce the complete documentation for the educational portal is **2 days**. This encompasses the creation of user manuals, administrator guides, API documentation, and training materials.
#
# ### Final Effort Estimates for the Project
# - **Requirements Gathering**: 4 days
# - **System Design**: 1 day
# - **Development**: 12 days
# - **Testing**: 18 days
# - **Documentation**: 2 days
#
# #### Total Project Effort Estimate
# - Total Effort: 4 + 1 + 12 + 18 + 2 = **37 days**
#
# I will now return these estimates to the project manager for final planning and scheduling. If you need any adjustments or have additional requirements to discuss, please let me know!
#
# --------------------------------------------------------------------------------
#
# Next speaker: Customer
#
# Customer (to chat_manager):
#
# ### Summary of Project Efforts for Educational Portal
#
# The comprehensive effort estimates gathered from the team members are outlined below, encapsulating all phases of the project:
#
# #### 1. **Requirement Gathering**: **4 days**
#    - Detailed requirements gathering and documentation for the educational portal.
#
# #### 2. **System Design**: **1 day**
#    - Creation of architecture diagrams, database schema, and API specifications.
#
# #### 3. **Development**: **12 days**
#    - Frontend components, backend services, and database integration to build the portal.
#
# #### 4. **Testing**: **18 days**
#    - Execution of unit tests, integration tests, UI tests, and performance tests to ensure quality.
#
# #### 5. **Documentation**: **2 days**
#    - Preparation of user manuals, administrator guides, API documentation, and training materials.
#
# ### Total Project Effort Estimate
# **Total Estimated Effort**:
# - \( 4 + 1 + 12 + 18 + 2 = 37 \) days
#
# ### Next Steps
# I will present this comprehensive project effort estimation to you for further planning and scheduling. If there are any adjustments, additional requirements or specific priorities you'd like to address, please feel free to share!
#
# --------------------------------------------------------------------------------
#
# Next speaker: Project_Manager
#
# Project_Manager (to chat_manager):
#
# ### Presentation of Project Plan for Educational Portal
#
# #### Comprehensive Project Effort Estimates
#
# Below are the summarized effort estimates for each phase of the educational portal project:
#
# | Phase               | Effort Estimate (Days) | Details                                                                                |
# |---------------------|-----------------------|----------------------------------------------------------------------------------------|
# | **Requirement Gathering** | 4                     | Detailed requirements gathering and documentation for the educational portal.        |
# | **System Design**       | 1                     | Creation of architecture diagrams, database schema, and API specifications.           |
# | **Development**         | 12                    | Frontend components, backend services, and database integration to build the portal.  |
# | **Testing**             | 18                    | Execution of unit tests, integration tests, UI tests, and performance tests to ensure quality. |
# | **Documentation**       | 2                     | Preparation of user manuals, administrator guides, API documentation, and training materials.  |
# | **Total Estimated Effort** | **37**                | **Overall estimate including all phases.**                                           |
#
# ### Next Steps
#
# - Please review this comprehensive project effort estimate.
# - If it meets your approval, we can move forward with finalizing the project schedule and initiating the development process.
# - Should you have any changes, additional requirements, or specific priorities, please let me know so I can adjust accordingly.
#
# I'm here to ensure that we align with your expectations and deliver a successful educational portal! Thank you for your cooperation!
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (52605b43-e753-434d-a84f-f51cb813172e): Maximum rounds (9) reached
